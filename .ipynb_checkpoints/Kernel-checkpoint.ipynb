# %% [markdown]
# # Predicting tsunami casualties
# ##### By Antoine Payan and Gaëlle Guillou

# %% [markdown]
# ### Introduction
#
# *Our objective*
#
# Tsunamis are an upcoming scientific challenge in their anticipation and the development of efficient solutions, as global warming hikes risk of landslide tsunamis. Predicting them is not an easy endeavour, and we shall leave that to others, but trying to anticipate their impact could have be of strong interest for insurance companies and governments.
#
# We based our work on a Kaggle Dataset from NOAA, *Tsunami Causes and Waves, Cause, magnitude, and intensity of every tsunami since 2000 BC*. We will be wondering the following:
#
# → Can we predict the occurence of Tsunamis, in terms of date, location?
#
# → If not, can we at least anticipate the human and physical damages for a given wave, seism?
#
# *Some information about tsunamis*
#
# Anything that rapidly displaces a large volume of water can cause a tsunami. Typically, tsunamis are caused by underwater earthquakes, but landslides, volcanic eruptions, calving icebergs, and (very rarely) meteorite impacts can also generate tsunamis. These types of events can cause large disturbances in the surface of the ocean, and when gravity pulls the water back down, the tsunami is born.
#
# "Tsunami" comes from the Japanese words for harbor ("tsu") and wave ("nami").
#
# *Can tsunamis be predicted?*
#
# Since earthquakes cannot be predicted, we do not know when a tsunami will happen before the earthquake occurs. Once a large potentially tsunamigenic earthquake does occur, we can forecast tsunami arrival times and wave heights through the use of computer modeling.
#
# [https://ptwc.weather.gov/faq.php#1]

# %% [markdown]
# ### Outline of the project
#
#
# 1. **EDA and visualisation**
# 2. **Missing values study**
# 4. **Looking into Tsunami casualties**
# 5. **Predictions and possible prevention**

# %%
# %matplotlib inline
import numpy as np 
import pandas as pd
import seaborn as sns
sns.set(rc={'figure.figsize':(9,5)})

import math

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap

# %% [markdown]
# ## 1. Exploratory data analysis and visualisation

# %%
waves = pd.read_csv('data/waves.csv')
sources = pd.read_csv('data/sources.csv')

# %% [markdown]
# #### Waves data

# %%
waves.head()
# Out:
#    SOURCE_ID  WAVE_ID  YEAR  MONTH  DAY  REGION_CODE COUNTRY STATE/PROVINCE  \
# 0          1    11014 -2000    NaN  NaN         50.0   SYRIA            NaN
# 1          3    17601 -1610    NaN  NaN         50.0   SYRIA            NaN
# 2          3        1 -1610    NaN  NaN         50.0  GREECE            NaN
# 3          9        2  -479    NaN  NaN         50.0  GREECE            NaN
# 4         10    19364  -426    6.0  NaN         50.0  GREECE            NaN
#
#                 LOCATION  LATITUDE  ...  INJURIES  INJURY_ESTIMATE  \
# 0                 UGARIT    35.583  ...       NaN              NaN
# 1                 UGARIT    35.583  ...       NaN              NaN
# 2  N. AND E. COAST CRETE    35.500  ...       NaN              NaN
# 3    POTIDAEA, MACEDONIA    40.300  ...       NaN              NaN
# 4                  TARFI       NaN  ...       NaN              NaN
#
#    FATALITIES  FATALITY_ESTIMATE DAMAGE_MILLIONS_DOLLARS  DAMAGE_ESTIMATE  \
# 0         NaN                3.0                     NaN              4.0
# 1         NaN                3.0                     NaN              3.0
# 2         NaN                3.0                     NaN              3.0
# 3         NaN                3.0                     NaN              NaN
# 4         NaN                NaN                     NaN              NaN
#
#    HOUSES_DAMAGED HOUSE_DAMAGE_ESTIMATE  HOUSES_DESTROYED  \
# 0             NaN                   NaN               NaN
# 1             NaN                   NaN               NaN
# 2             NaN                   NaN               NaN
# 3             NaN                   NaN               NaN
# 4             NaN                   NaN               NaN
#
#    HOUSE_DESTRUCTION_ESTIMATE
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
#
# [5 rows x 30 columns]

# %%
waves.describe()
# Out:
#           SOURCE_ID       WAVE_ID          YEAR         MONTH           DAY  \
# count  26203.000000  26203.000000  26203.000000  26099.000000  25990.000000
# mean    3146.880434  16701.682937   1959.461207      6.133990     15.326048
# std     1718.398292   8999.325433    135.750038      3.504212      8.519406
# min        1.000000      1.000000  -2000.000000      1.000000      1.000000
# 25%     1884.000000   9393.500000   1952.000000      3.000000     11.000000
# 50%     2406.000000  16986.000000   1996.000000      5.000000     12.000000
# 75%     5413.000000  23998.500000   2011.000000      9.000000     23.000000
# max     5642.000000  32418.000000   2017.000000     12.000000     31.000000
#
#         REGION_CODE      LATITUDE     LONGITUDE  DISTANCE_FROM_SOURCE  \
# count  26202.000000  25591.000000  25591.000000          25320.000000
# mean      80.779330     21.819451     50.248786           2463.739573
# std        9.637029     24.936755    121.136966           4217.066399
# min       30.000000    -77.850000   -179.876000              0.000000
# 25%       81.000000      5.480500    -73.158000            112.000000
# 50%       85.000000     34.500000    133.250000            255.000000
# 75%       85.000000     39.034970    141.500000           3439.750000
# max       89.000000     70.250000    179.367000          19331.000000
#
#        TRAVEL_TIME_HOURS  ...     INJURIES  INJURY_ESTIMATE     FATALITIES  \
# count        3272.000000  ...   123.000000       129.000000     683.000000
# mean            6.596577  ...   131.260163         1.550388    1258.500732
# std             7.198404  ...   407.925436         0.856603   13460.721455
# min             0.000000  ...     1.000000         1.000000       0.000000
# 25%             1.000000  ...     2.000000         1.000000       3.000000
# 50%             4.000000  ...    12.000000         1.000000      18.000000
# 75%            11.000000  ...    68.000000         2.000000     133.000000
# max            47.000000  ...  2943.000000         4.000000  300000.000000
#
#        FATALITY_ESTIMATE  DAMAGE_MILLIONS_DOLLARS  DAMAGE_ESTIMATE  \
# count         904.000000               135.000000      1887.000000
# mean            1.829646              1714.728926         1.424483
# std             1.035240             18931.934914         0.757777
# min             1.000000                 0.001000         0.000000
# 25%             1.000000                 0.050000         1.000000
# 50%             1.000000                 0.500000         1.000000
# 75%             3.000000                 9.750000         2.000000
# max             4.000000            220000.000000         4.000000
#
#        HOUSES_DAMAGED  HOUSE_DAMAGE_ESTIMATE  HOUSES_DESTROYED  \
# count      162.000000             402.000000        292.000000
# mean       522.012346               1.868159       1874.808219
# std       3070.279840               2.176737      16486.712040
# min          1.000000               1.000000          1.000000
# 25%         10.000000               1.000000          4.000000
# 50%         38.500000               1.000000         24.000000
# 75%        266.750000               3.000000        151.250000
# max      38561.000000              33.000000     235377.000000
#
#        HOUSE_DESTRUCTION_ESTIMATE
# count                  758.000000
# mean                     1.799472
# std                      0.939040
# min                      1.000000
# 25%                      1.000000
# 50%                      1.000000
# 75%                      3.000000
# max                      4.000000
#
# [8 rows x 25 columns]

# %% [markdown]
# #### Sources data

# %%
sources.head()
# Out:
#    SOURCE_ID  YEAR  MONTH  DAY  HOUR  MINUTE  CAUSE  VALIDITY  FOCAL_DEPTH  \
# 0          1 -2000    NaN  NaN   NaN     NaN    1.0       1.0          NaN
# 1          3 -1610    NaN  NaN   NaN     NaN    6.0       4.0          NaN
# 2          4 -1365    NaN  NaN   NaN     NaN    1.0       1.0          NaN
# 3          5 -1300    NaN  NaN   NaN     NaN    0.0       2.0          NaN
# 4          6  -760    NaN  NaN   NaN     NaN    0.0       2.0          NaN
#
#    PRIMARY_MAGNITUDE  ...  ALL_INJURIES INJURY_TOTAL ALL_FATALITIES  \
# 0                NaN  ...           NaN          NaN            NaN
# 1                NaN  ...           NaN          NaN            NaN
# 2                NaN  ...           NaN          NaN            NaN
# 3                6.0  ...           NaN          NaN            NaN
# 4                NaN  ...           NaN          NaN            NaN
#
#   FATALITY_TOTAL  ALL_DAMAGE_MILLIONS  DAMAGE_TOTAL  ALL_HOUSES_DAMAGED  \
# 0            3.0                  NaN           4.0                 NaN
# 1            3.0                  NaN           3.0                 NaN
# 2            NaN                  NaN           3.0                 NaN
# 3            NaN                  NaN           NaN                 NaN
# 4            NaN                  NaN           NaN                 NaN
#
#    HOUSE_DAMAGE_TOTAL  ALL_HOUSES_DESTROYED  HOUSE_DESTRUCTION_TOTAL
# 0                 NaN                   NaN                      NaN
# 1                 NaN                   NaN                      NaN
# 2                 NaN                   NaN                      NaN
# 3                 NaN                   NaN                      NaN
# 4                 NaN                   NaN                      NaN
#
# [5 rows x 45 columns]

# %%
sources.describe()
# Out:
#          SOURCE_ID         YEAR        MONTH          DAY         HOUR  \
# count  2582.000000  2582.000000  2443.000000  2341.000000  1319.000000
# mean   2132.966692  1805.891944     6.621367    15.618539    11.319939
# std    1546.994278   350.752703     3.486535     8.680274     6.929352
# min       1.000000 -2000.000000     1.000000     1.000000     0.000000
# 25%     940.250000  1818.000000     4.000000     8.000000     5.000000
# 50%    1797.500000  1895.000000     7.000000    16.000000    11.000000
# 75%    3148.750000  1956.000000    10.000000    23.000000    17.000000
# max    5642.000000  2017.000000    12.000000    31.000000    23.000000
#
#             MINUTE        CAUSE     VALIDITY  FOCAL_DEPTH  PRIMARY_MAGNITUDE  \
# count  1233.000000  2576.000000  2580.000000   867.000000        1459.000000
# mean     28.225466     1.786879     2.334109    36.205306           7.038725
# std      17.202228     2.260681     1.558476    37.163354           0.803739
# min       0.000000     0.000000    -1.000000     0.000000           3.200000
# 25%      14.000000     1.000000     1.000000    19.000000           6.600000
# 50%      29.000000     1.000000     2.000000    33.000000           7.000000
# 75%      43.000000     1.000000     4.000000    40.000000           7.600000
# max      59.000000    11.000000     4.000000   600.000000           9.500000
#
#        ...   ALL_INJURIES  INJURY_TOTAL  ALL_FATALITIES  FATALITY_TOTAL  \
# count  ...     223.000000    263.000000      522.000000      653.000000
# mean   ...    5334.354260      2.304183     4380.680077        2.229709
# std    ...   32961.882201      1.125122    20610.548682        1.214397
# min    ...       1.000000      1.000000        1.000000        1.000000
# 25%    ...      19.500000      1.000000        7.000000        1.000000
# 50%    ...     100.000000      3.000000       56.000000        2.000000
# 75%    ...     511.000000      3.000000     1001.000000        3.000000
# max    ...  374171.000000      4.000000   316000.000000        4.000000
#
#        ALL_DAMAGE_MILLIONS  DAMAGE_TOTAL  ALL_HOUSES_DAMAGED  \
# count           116.000000   1006.000000           52.000000
# mean           4805.086534      2.186879        29188.826923
# std           24019.330461      1.046609        86723.543401
# min               0.003000      1.000000            2.000000
# 25%               1.780750      1.000000          119.250000
# 50%              30.000000      2.000000          820.000000
# 75%             500.000000      3.000000         6851.500000
# max          220085.456000      4.000000       500000.000000
#
#        HOUSE_DAMAGE_TOTAL  ALL_HOUSES_DESTROYED  HOUSE_DESTRUCTION_TOTAL
# count          145.000000          2.060000e+02               575.000000
# mean             2.268966          3.794183e+04                 2.690435
# std              1.094527          3.767096e+05                 0.999039
# min              1.000000          1.000000e+00                 1.000000
# 25%              1.000000          7.075000e+01                 2.000000
# 50%              2.000000          7.000000e+02                 3.000000
# 75%              3.000000          3.000000e+03                 3.000000
# max              4.000000          5.360000e+06                 4.000000
#
# [8 rows x 42 columns]

# %% [markdown]
# #### Visualising main informations

# %%
plt.figure(figsize=(20,12))

map = Basemap(lat_0=0, lon_0=0)

map.drawmapboundary(fill_color='lightblue')
map.fillcontinents(color='green',lake_color='lightblue')
map.drawcoastlines()

lons_w = waves.LONGITUDE.tolist()
lats_w = waves.LATITUDE.tolist()

lons_s = sources.LONGITUDE.tolist()
lats_s = sources.LATITUDE.tolist()

xw, yw = map(lons_w, lats_w)
xs, ys = map(lons_s, lats_s)

map.scatter(xw, yw, marker='D',color='R', s=[math.sqrt(h) * 20 if h else 0 for h in waves.MAXIMUM_HEIGHT])
map.scatter(xs, ys, marker='D',color='B', s=[m * 3 if m else 0 for m in sources.PRIMARY_MAGNITUDE])


plt.show()

# %% [markdown]
# Waves (in red) and sources (in blue) of the tsunamis, with size relative to their height / magnitude. The tecnonic plaques subtly appear in this map.

# %%
waves.columns
# Out:
# Index(['SOURCE_ID', 'WAVE_ID', 'YEAR', 'MONTH', 'DAY', 'REGION_CODE',
#        'COUNTRY', 'STATE/PROVINCE', 'LOCATION', 'LATITUDE', 'LONGITUDE',
#        'DISTANCE_FROM_SOURCE', 'TRAVEL_TIME_HOURS', 'TRAVEL_TIME_MINUTES',
#        'VALIDITY', 'MEASUREMENT_TYPE', 'PERIOD', 'FIRST_MOTION',
#        'MAXIMUM_HEIGHT', 'HORIZONTAL_INUNDATION', 'INJURIES',
#        'INJURY_ESTIMATE', 'FATALITIES', 'FATALITY_ESTIMATE',
#        'DAMAGE_MILLIONS_DOLLARS', 'DAMAGE_ESTIMATE', 'HOUSES_DAMAGED',
#        'HOUSE_DAMAGE_ESTIMATE', 'HOUSES_DESTROYED',
#        'HOUSE_DESTRUCTION_ESTIMATE'],
#       dtype='object')

# %% [markdown]
# ### Looking into tsunamis historically

# %% [markdown]
# In short: the number of tsunamis **on record** has known an exponential growth over the last decade.

# %%
sns.set_style("whitegrid")

ax = sns.relplot(x = "YEAR", 
            y = "WAVE_ID",
            data = waves[waves.YEAR > 1850].groupby("YEAR").count()["WAVE_ID"].reset_index(),
                 kind = 'line')

ax.set(xlabel='Year', ylabel='Wave count')
plt.show()

# %%
sns.set_style("whitegrid")

ax = sns.catplot(x = "MONTH",
                y = "WAVE_ID",
                data = waves.groupby("MONTH").count()['WAVE_ID'].reset_index(),
                kind = 'bar')

ax.set(xlabel='Month', ylabel='Wave count')
plt.show()

# %% [markdown]
# Though there is no clear trend of seasonality (since most tsunamis are caused by earthquakes, and earthquakes are not subject to seasons), it is quite obvious that some months have had a much larger share of tsunami waves, namely March (3), May (5), December (12).

# %% [markdown]
# ### Exploring geographical patterns

# %%
def plot_wave_count(cat = "COUNTRY", n = 10, sort = True, log = True):
    
    sns.set_style("whitegrid")
    
    data_grouped = waves.groupby(cat).count()['WAVE_ID'].reset_index()
    
    data_grouped[cat] = data_grouped[cat].astype(str)
    
    if sort:
        data_grouped = data_grouped.sort_values("WAVE_ID", ascending = False)
        
        
    if n is not None :
        data_grouped = data_grouped.head(n)
    
    ax = sns.catplot(x = cat,
                    y = "WAVE_ID",
                    data = data_grouped,
                    kind = 'bar',
                    row_order = [cat, "WAVE_ID"])

    ax.set(xlabel = cat.capitalize(), ylabel='Wave count', title = 'Wave count by ' + cat.capitalize())
    
    if log:
        ax.set(yscale="log")
    
    ax.set_xticklabels(rotation=90)
    
    return ax

# %%
plot_wave_count("COUNTRY", log = True);

# %%
plot_wave_count("STATE/PROVINCE", log = False);

# %% [markdown]
# As one could expect, some regions are much more susceptible to experience tsunamis, Japan for instance.

# %% [markdown]
# ### Exploring relationships between variables

# %%
C = waves.drop(['SOURCE_ID', 
                'WAVE_ID',
                'LATITUDE',
                'LONGITUDE'], 1).corr()

cutoff_corr = 0.3

mask = np.zeros_like(C, dtype=np.bool)
mask[(C < cutoff_corr) & (C > -cutoff_corr)] = True
mask[np.triu_indices_from(mask)] = True

cmap = sns.diverging_palette(220, 10, as_cmap=True)

sns.heatmap(data = C,
            xticklabels = C.columns,
            yticklabels = C.columns,
            mask = mask,
            cmap = cmap);

# %% [markdown]
# As we can see, even with a fair cutoff value (0.3), most correlations are between the injuries, damages and houses, which makes a lot of sense. However, it means we will have trouble figuring out how to predict damages and fatalities, but that it should be easier to fill in missing values.

# %%
f, ax = plt.subplots(figsize=(7, 5))

ax.set(xscale="log", yscale="log")

sns.regplot(x = "MAXIMUM_HEIGHT", 
            y = "FATALITIES",
           data = waves, ax=ax, scatter_kws={"s": 100});

# %% [markdown]
# The relationship between height and fatalities is perhaps not what you would expect: the positive linear relationship barely exists for extreme values.

# %% [markdown]
# ## 2. Missing values study

# %%
waves.isna().sum() / waves.shape[0]
# Out:
# SOURCE_ID                     0.000000
# WAVE_ID                       0.000000
# YEAR                          0.000000
# MONTH                         0.003969
# DAY                           0.008129
# REGION_CODE                   0.000038
# COUNTRY                       0.000114
# STATE/PROVINCE                0.198336
# LOCATION                      0.000191
# LATITUDE                      0.023356
# LONGITUDE                     0.023356
# DISTANCE_FROM_SOURCE          0.033698
# TRAVEL_TIME_HOURS             0.875129
# TRAVEL_TIME_MINUTES           0.876083
# VALIDITY                      0.987521
# MEASUREMENT_TYPE              0.011029
# PERIOD                        0.915048
# FIRST_MOTION                  0.940808
# MAXIMUM_HEIGHT                0.147846
# HORIZONTAL_INUNDATION         0.664504
# INJURIES                      0.995306
# INJURY_ESTIMATE               0.995077
# FATALITIES                    0.973934
# FATALITY_ESTIMATE             0.965500
# DAMAGE_MILLIONS_DOLLARS       0.994848
# DAMAGE_ESTIMATE               0.927985
# HOUSES_DAMAGED                0.993818
# HOUSE_DAMAGE_ESTIMATE         0.984658
# HOUSES_DESTROYED              0.988856
# HOUSE_DESTRUCTION_ESTIMATE    0.971072
# dtype: float64

# %% [markdown]
# ## 3. Looking into Tsunami casualties

# %% [markdown]
# ## 5. **Predictions and possible prevention**

# %% [markdown]
# ## Conclusion
